# %% [markdown]
# # # Proecto 01

# %% [markdown]
# # Mostrar informacion al suario

# %% [markdown]
# . print ()

# %%
print ("semana de python en la prativa")
print("hola mundo")
# Out:
# semana de python en la prativa
# hola mundo

# %% [markdown]
# # Recibir informacion del usuario
# . input ()

# %%
input("ingrese su nombre")
input("ingrese su contraseña")
# Out:
# '32444'

# %% [markdown]
# # Almacenar variables
# imagina que una variable es como la cabeza o como pensamos

# %%
proyecto = "Mi primer proyecto en python"

# %%
print(proyecto)
# Out:
# Mi primer proyecto en python

# %% [markdown]
# ## Mezclando todos los conceptos aprendidos

# %%
Proyecto = input ("escriba el nombre del proyecto")
Horas_estimadas = input ("ingrese las horas estimadas dedicadas al proyecto")
Valor_hora = input ("¿cual es el valor de la hora trabajada?")
Plazo_estimado = input ("¿cuantos dias/meses se estima que va a durar el proyecto?")

# %%
print(Proyecto)
print (Horas_estimadas)
print (Valor_hora)
print (Plazo_estimado)
# Out:
# la ptm
# 120
# 20
# 2 meses

# %% [markdown]
# ## Calculos con Python

# %%
print(10+4)
print (123-23)
print (12*3)
print (12/2)
# Out:
# 14
# 100
# 36
# 6.0

# %% [markdown]
# ## Calculando el valor total del proyecto

# %%
Valor_total = int(Horas_estimadas) * int(Valor_hora)

# %%
print(Valor_total)
# Out:
# 2400

# %% [markdown]
# ## Generando archivos PDF del presupuesto
# * Crear el archivo PDF
# * Definir tipo de letra
# * Como llenar el documento
# * Guardar documento

# %%
# !pip install fpdf
# Out:
# ...
#   Using cached fpdf-1.7.2.tar.gz (39 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for fpdf: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40770 sha256=cbb99cfd4090740a61afaae8cd3139481885ecf137d132f6a3d6e769ff4daf28
#   Stored in directory: c:\users\alfredo\appdata\local\pip\cache\wheels\65\4f\66\bbda9866da446a72e206d6484cd97381cbc7859a7068541c36
# Successfully built fpdf
# ...
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: C:\Users\Alfredo\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from fpdf  import FPDF

# %%
pdf = FPDF ()

pdf.add_page()
pdf. set_font("Arial")

pdf.image("Template.png", 0, 0)

pdf.text(115, 145, Proyecto)
pdf.text(115, 160, Horas_estimadas)
pdf.text(115, 175, Valor_hora)
pdf.text(115, 190, Plazo_estimado)
pdf.text(115, 205, str(Valor_total))

pdf. output("proyecto.pdf")
# Out:
# ''
